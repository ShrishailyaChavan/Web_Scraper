# %%
import numpy as np
import os
import requests
import pandas as pd
import urllib.request
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
cols = [0,11]
df = pd.read_csv('Files/content_1.csv', names=['PID', 'Image'], usecols=cols)
df.head()
# Out:
#    PID                                              Image
# 0  PID                                              Image
# 1    6  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2   15  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3   16  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4   56  https://images.vgsi.com/photos2/WorcesterMAPho...

# %%
df = pd.read_csv('Files/content_1.csv')
df.shape
# Out:
# (3204, 17)

# %%
df.columns[11]
# Out:
# 'Image'

# %%
cols = [0,11]
df = pd.read_csv('Files/content_1.csv', usecols=cols)
df
# Out:
#         PID                                              Image
# 0         6  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1        15  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2        16  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3        56  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4        57  https://images.vgsi.com/photos2/WorcesterMAPho...
# ...     ...                                                ...
# 3199  60878  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3200  60879  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3201  60881  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3202  61137  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3203  62576  https://images.vgsi.com/photos2/WorcesterMAPho...
#
# [3204 rows x 2 columns]

# %%
df
# Out:
#         PID                                              Image
# 0         6  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1        15  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2        16  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3        56  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4        57  https://images.vgsi.com/photos2/WorcesterMAPho...
# ...     ...                                                ...
# 3199  60878  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3200  60879  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3201  60881  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3202  61137  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3203  62576  https://images.vgsi.com/photos2/WorcesterMAPho...
#
# [3204 rows x 2 columns]

# %%
opener=urllib.request.build_opener()
opener.addheaders=[('User-Agent','Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1941.0 Safari/537.36')]
urllib.request.install_opener(opener)

result = df['Image'].isna().any()

print(result)

missed_PID = []
missed_links = []


for index, row in df.iterrows():
    createFileName = 'Images/1/' + str(row['PID']) + '.jpg'
    image_url = str(row['Image'])
    print('Image_url',image_url)
    try:
        urllib.request.urlretrieve(image_url, createFileName)
    except:
        print('Missing Image for PID',str(row['PID']))
        print('Missing Image for PID',str(row['Image']))
        missed_PID.append(str(row['PID']))
        missed_links.append(str(row['Image']))
# Out:
# False
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0136\DSC02848_136813.JPG
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0136\DSC02852_136817.JPG
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\06\44\90.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0136\20210514_091048_136706.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0132\DSC01735_132028.JPG
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\00\49\42.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0136\DSC02843_136809.JPG
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0142\IMG_3097_142079.JPG
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0136\DSC02844_136810.JPG
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0132\DSC01796_132339.JPG
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0136\DSC02842_136808.JPG
# ...

# %%
cols = [0,11]
df = pd.read_csv('Files/content_2.csv', names=['PID', 'Image'], usecols=cols)
df.head()
# Out:
#    PID                                              Image
# 0  PID                                              Image
# 1    9  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2   22  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3   54  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4   65  https://images.vgsi.com/photos2/WorcesterMAPho...

# %%
df = pd.read_csv('Files/content_2.csv')
df.shape
# Out:
# (2778, 17)

# %%
df.columns[11]
# Out:
# 'Image'

# %%
cols = [0,11]
df = pd.read_csv('Files/content_2.csv', usecols=cols)
df
# Out:
#         PID                                              Image
# 0         9  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1        22  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2        54  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3        65  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4       174  https://images.vgsi.com/photos2/WorcesterMAPho...
# ...     ...                                                ...
# 2773  58037  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2774  59239  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2775  61375  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2776  62145  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2777  62362  https://images.vgsi.com/photos2/WorcesterMAPho...
#
# [2778 rows x 2 columns]

# %%
df
# Out:
#         PID                                              Image
# 0         9  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1        22  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2        54  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3        65  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4       174  https://images.vgsi.com/photos2/WorcesterMAPho...
# ...     ...                                                ...
# 2773  58037  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2774  59239  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2775  61375  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2776  62145  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2777  62362  https://images.vgsi.com/photos2/WorcesterMAPho...
#
# [2778 rows x 2 columns]

# %%
opener=urllib.request.build_opener()
opener.addheaders=[('User-Agent','Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1941.0 Safari/537.36')]
urllib.request.install_opener(opener)

result = df['Image'].isna().any()

print(result)

missed_PID = []
missed_links = []


for index, row in df.iterrows():
    createFileName = 'Images/2/' + str(row['PID']) + '.jpg'
    image_url = str(row['Image'])
    print('Image_url',image_url)
    try:
        urllib.request.urlretrieve(image_url, createFileName)
    except:
        print('Missing Image for PID',str(row['PID']))
        print('Missing Image for PID',str(row['Image']))
        missed_PID.append(str(row['PID']))
        missed_links.append(str(row['Image']))
# Out:
# False
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0136\DSC02846_136811.JPG
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\09\85\71.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0131\DSC01600_131718.JPG
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\13\96\04.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0130\DSC01471_130834.JPG
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0132\DSC01712_132009.JPG
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\08\25\48.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\04\01-028-00025.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\04\01-029-00035.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0137\DSC02983_137147.JPG
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\06\61\79.jpg
# ...

# %%
cols = [0,11]
df = pd.read_csv('Files/content_3.csv', names=['PID', 'Image'], usecols=cols)
df.head()
# Out:
#    PID                                              Image
# 0  PID                                              Image
# 1   19  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2  346  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3  733  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4  861  https://images.vgsi.com/photos2/WorcesterMAPho...

# %%
df = pd.read_csv('Files/content_3.csv')
df.shape
# Out:
# (1524, 17)

# %%
df.columns[11]
# Out:
# 'Image'

# %%
cols = [0,11]
df = pd.read_csv('Files/content_3.csv', usecols=cols)
df
# Out:
#         PID                                              Image
# 0        19  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1       346  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2       733  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3       861  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4       869  https://images.vgsi.com/photos2/WorcesterMAPho...
# ...     ...                                                ...
# 1519  56328  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1520  57784  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1521  58417  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1522  59564  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1523  60120  https://images.vgsi.com/photos2/WorcesterMAPho...
#
# [1524 rows x 2 columns]

# %%
df
# Out:
#         PID                                              Image
# 0        19  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1       346  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2       733  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3       861  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4       869  https://images.vgsi.com/photos2/WorcesterMAPho...
# ...     ...                                                ...
# 1519  56328  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1520  57784  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1521  58417  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1522  59564  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1523  60120  https://images.vgsi.com/photos2/WorcesterMAPho...
#
# [1524 rows x 2 columns]

# %%
opener=urllib.request.build_opener()
opener.addheaders=[('User-Agent','Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1941.0 Safari/537.36')]
urllib.request.install_opener(opener)

result = df['Image'].isna().any()

print(result)

missed_PID = []
missed_links = []


for index, row in df.iterrows():
    createFileName = 'Images/3/' + str(row['PID']) + '.jpg'
    image_url = str(row['Image'])
    print('Image_url',image_url)
    try:
        urllib.request.urlretrieve(image_url, createFileName)
    except:
        print('Missing Image for PID',str(row['PID']))
        print('Missing Image for PID',str(row['Image']))
        missed_PID.append(str(row['PID']))
        missed_links.append(str(row['Image']))
# Out:
# False
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\13\96\06.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\04\01-032-00007.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\12\27\97.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\13\26\57.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\10\02-037-00042.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\13\21\70.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\12\02-043-00128.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\13\24\73.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\12\02-043-00153.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\06\50\36.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\12\02-043-00156.jpg
# ...

# %%
cols = [0,11]
df = pd.read_csv('Files/content_4.csv', names=['PID', 'Image'], usecols=cols)
df.head()
# Out:
#    PID                                              Image
# 0  PID                                              Image
# 1   32  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2  172  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3  182  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4  210  https://images.vgsi.com/photos2/WorcesterMAPho...

# %%
df = pd.read_csv('Files/content_4.csv')
df.shape
# Out:
# (2400, 17)

# %%
df.columns[11]
# Out:
# 'Image'

# %%
cols = [0,11]
df = pd.read_csv('Files/content_4.csv', usecols=cols)
df
# Out:
#         PID                                              Image
# 0        32  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1       172  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2       182  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3       210  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4       212  https://images.vgsi.com/photos2/WorcesterMAPho...
# ...     ...                                                ...
# 2395  56475  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2396  57311  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2397  59900  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2398  60737  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2399  60757  https://images.vgsi.com/photos2/WorcesterMAPho...
#
# [2400 rows x 2 columns]

# %%
df
# Out:
#         PID                                              Image
# 0        32  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1       172  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2       182  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3       210  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4       212  https://images.vgsi.com/photos2/WorcesterMAPho...
# ...     ...                                                ...
# 2395  56475  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2396  57311  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2397  59900  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2398  60737  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2399  60757  https://images.vgsi.com/photos2/WorcesterMAPho...
#
# [2400 rows x 2 columns]

# %%
opener=urllib.request.build_opener()
opener.addheaders=[('User-Agent','Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1941.0 Safari/537.36')]
urllib.request.install_opener(opener)

result = df['Image'].isna().any()

print(result)

missed_PID = []
missed_links = []


for index, row in df.iterrows():
    createFileName = 'Images/4/' + str(row['PID']) + '.jpg'
    image_url = str(row['Image'])
    print('Image_url',image_url)
    try:
        urllib.request.urlretrieve(image_url, createFileName)
    except:
        print('Missing Image for PID',str(row['PID']))
        print('Missing Image for PID',str(row['Image']))
        missed_PID.append(str(row['PID']))
        missed_links.append(str(row['Image']))
# Out:
# False
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0132\DSC01737_132030.JPG
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\03\01-01D-00005.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0132\DSC01738_132032.JPG
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\11\39\96.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0131\DSC01700_131986.JPG
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0137\DSC02997_137120.JPG
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\12\08\62.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\08\33\15.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0131\20200915_091349_131033.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\07\43\20.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0131\20200915_115943_131069.jpg
# ...

# %%
cols = [0,11]
df = pd.read_csv('Files/content_5.csv', names=['PID', 'Image'], usecols=cols)
df.head()
# Out:
#    PID                                              Image
# 0  PID                                              Image
# 1  175  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2  177  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3  178  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4  180  https://images.vgsi.com/photos2/WorcesterMAPho...

# %%
df = pd.read_csv('Files/content_5.csv')
df.shape
# Out:
# (2706, 17)

# %%
df.columns[11]
# Out:
# 'Image'

# %%
cols = [0,11]
df = pd.read_csv('Files/content_5.csv', usecols=cols)
df
# Out:
#         PID                                              Image
# 0       175  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1       177  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2       178  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3       180  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4       181  https://images.vgsi.com/photos2/WorcesterMAPho...
# ...     ...                                                ...
# 2701  56443  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2702  56470  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2703  56472  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2704  57383  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2705  57797  https://images.vgsi.com/photos2/WorcesterMAPho...
#
# [2706 rows x 2 columns]

# %%
df
# Out:
#         PID                                              Image
# 0       175  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1       177  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2       178  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3       180  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4       181  https://images.vgsi.com/photos2/WorcesterMAPho...
# ...     ...                                                ...
# 2701  56443  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2702  56470  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2703  56472  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2704  57383  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2705  57797  https://images.vgsi.com/photos2/WorcesterMAPho...
#
# [2706 rows x 2 columns]

# %%
opener=urllib.request.build_opener()
opener.addheaders=[('User-Agent','Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1941.0 Safari/537.36')]
urllib.request.install_opener(opener)

result = df['Image'].isna().any()

print(result)

missed_PID = []
missed_links = []


for index, row in df.iterrows():
    createFileName = 'Images/5/' + str(row['PID']) + '.jpg'
    image_url = str(row['Image'])
    print('Image_url',image_url)
    try:
        urllib.request.urlretrieve(image_url, createFileName)
    except:
        print('Missing Image for PID',str(row['PID']))
        print('Missing Image for PID',str(row['Image']))
        missed_PID.append(str(row['PID']))
        missed_links.append(str(row['Image']))
# Out:
# False
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\03\01-01E-00002.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\03\01-01E-00004.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\03\01-01E-00005.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0128\DSC04173_128499.JPG
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\08\13\30.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\12\02-042-00050.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\12\79\29.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0137\DSC03112_137334.JPG
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\07\69\11.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\07\31\33.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0135\DSC02539_135934.JPG
# ...

# %%
cols = [0,11]
df = pd.read_csv('Files/content_6.csv', names=['PID', 'Image'], usecols=cols)
df.head()
# Out:
#    PID                                              Image
# 0  PID                                              Image
# 1  545  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2  565  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3  579  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4  592  https://images.vgsi.com/photos2/WorcesterMAPho...

# %%
df = pd.read_csv('Files/content_6.csv')
df.shape
# Out:
# (2185, 17)

# %%
df.columns[11]
# Out:
# 'Image'

# %%
cols = [0,11]
df = pd.read_csv('Files/content_6.csv', usecols=cols)
df
# Out:
#         PID                                              Image
# 0       545  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1       565  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2       579  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3       592  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4       605  https://images.vgsi.com/photos2/WorcesterMAPho...
# ...     ...                                                ...
# 2180  56517  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2181  57697  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2182  59080  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2183  61404  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2184  61405  https://images.vgsi.com/photos2/WorcesterMAPho...
#
# [2185 rows x 2 columns]

# %%
df
# Out:
#         PID                                              Image
# 0       545  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1       565  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2       579  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3       592  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4       605  https://images.vgsi.com/photos2/WorcesterMAPho...
# ...     ...                                                ...
# 2180  56517  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2181  57697  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2182  59080  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2183  61404  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2184  61405  https://images.vgsi.com/photos2/WorcesterMAPho...
#
# [2185 rows x 2 columns]

# %%
opener=urllib.request.build_opener()
opener.addheaders=[('User-Agent','Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1941.0 Safari/537.36')]
urllib.request.install_opener(opener)

result = df['Image'].isna().any()

print(result)

missed_PID = []
missed_links = []


for index, row in df.iterrows():
    createFileName = 'Images/6/' + str(row['PID']) + '.jpg'
    image_url = str(row['Image'])
    print('Image_url',image_url)
    try:
        urllib.request.urlretrieve(image_url, createFileName)
    except:
        print('Missing Image for PID',str(row['PID']))
        print('Missing Image for PID',str(row['Image']))
        missed_PID.append(str(row['PID']))
        missed_links.append(str(row['Image']))
# Out:
# False
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0131\20200915_113203_131627.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0134\DSC02330_134602.JPG
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0131\20200915_113203_131061.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0136\20210517_112448_136765.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0136\20210517_112448_136764.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\00\23\42.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\21\04-011-00039.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\09\79\62.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\53\06-039-00038.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\64\07-033-00034.jpg
# ...

# %%
cols = [0,11]
df = pd.read_csv('Files/content_7.csv', names=['PID', 'Image'], usecols=cols)
df.head()
# Out:
#    PID                                              Image
# 0  PID                                              Image
# 1   10  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2  257  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3  311  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4  458  https://images.vgsi.com/photos2/WorcesterMAPho...

# %%
df = pd.read_csv('Files/content_7.csv')
df.shape
# Out:
# (2587, 17)

# %%
df.columns[11]
# Out:
# 'Image'

# %%
cols = [0,11]
df = pd.read_csv('Files/content_7.csv', usecols=cols)
df
# Out:
#         PID                                              Image
# 0        10  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1       257  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2       311  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3       458  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4      1329  https://images.vgsi.com/photos2/WorcesterMAPho...
# ...     ...                                                ...
# 2582  62242  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2583  62255  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2584  62257  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2585  62518  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2586  62541  https://images.vgsi.com/photos2/WorcesterMAPho...
#
# [2587 rows x 2 columns]

# %%
df
# Out:
#         PID                                              Image
# 0        10  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1       257  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2       311  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3       458  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4      1329  https://images.vgsi.com/photos2/WorcesterMAPho...
# ...     ...                                                ...
# 2582  62242  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2583  62255  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2584  62257  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2585  62518  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2586  62541  https://images.vgsi.com/photos2/WorcesterMAPho...
#
# [2587 rows x 2 columns]

# %%
opener=urllib.request.build_opener()
opener.addheaders=[('User-Agent','Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1941.0 Safari/537.36')]
urllib.request.install_opener(opener)

result = df['Image'].isna().any()

print(result)

missed_PID = []
missed_links = []


for index, row in df.iterrows():
    createFileName = 'Images/7/' + str(row['PID']) + '.jpg'
    image_url = str(row['Image'])
    print('Image_url',image_url)
    try:
        urllib.request.urlretrieve(image_url, createFileName)
    except:
        print('Missing Image for PID',str(row['PID']))
        print('Missing Image for PID',str(row['Image']))
        missed_PID.append(str(row['PID']))
        missed_links.append(str(row['Image']))
# Out:
# False
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\01\01-009-0008B.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\04\01-028-00010.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\11\40\21.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0132\DSC01740_132116.JPG
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\10\75\66.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\09\57\85.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0137\20210715_100823_137810.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\19\04-005-00026.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\07\43\13.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\08\40\78.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\09\57\60.jpg
# ...

# %%
cols = [0,11]
df = pd.read_csv('Files/content_8.csv', names=['PID', 'Image'], usecols=cols)
df.head()
# Out:
#    PID                                              Image
# 0  PID                                              Image
# 1   34  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2   70  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3   74  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4  251  https://images.vgsi.com/photos2/WorcesterMAPho...

# %%
df = pd.read_csv('Files/content_8.csv')
df.shape
# Out:
# (2377, 17)

# %%
df.columns[11]
# Out:
# 'Image'

# %%
cols = [0,11]
df = pd.read_csv('Files/content_8.csv', usecols=cols)
df
# Out:
#         PID                                              Image
# 0        34  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1        70  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2        74  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3       251  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4       753  https://images.vgsi.com/photos2/WorcesterMAPho...
# ...     ...                                                ...
# 2372  60858  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2373  61960  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2374  61966  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2375  62197  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2376  62198  https://images.vgsi.com/photos2/WorcesterMAPho...
#
# [2377 rows x 2 columns]

# %%
df
# Out:
#         PID                                              Image
# 0        34  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1        70  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2        74  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3       251  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4       753  https://images.vgsi.com/photos2/WorcesterMAPho...
# ...     ...                                                ...
# 2372  60858  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2373  61960  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2374  61966  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2375  62197  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2376  62198  https://images.vgsi.com/photos2/WorcesterMAPho...
#
# [2377 rows x 2 columns]

# %%
opener=urllib.request.build_opener()
opener.addheaders=[('User-Agent','Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1941.0 Safari/537.36')]
urllib.request.install_opener(opener)

result = df['Image'].isna().any()

print(result)

missed_PID = []
missed_links = []


for index, row in df.iterrows():
    createFileName = 'Images/8/' + str(row['PID']) + '.jpg'
    image_url = str(row['Image'])
    print('Image_url',image_url)
    try:
        urllib.request.urlretrieve(image_url, createFileName)
    except:
        print('Missing Image for PID',str(row['PID']))
        print('Missing Image for PID',str(row['Image']))
        missed_PID.append(str(row['PID']))
        missed_links.append(str(row['Image']))
# Out:
# False
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\10\89\11.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\09\59\88.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0136\DSC02849_136814.JPG
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0134\DSC02374_134996.JPG
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\09\59\90.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\17\03-024-00016.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\09\01\03.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0131\20200915_120219_131621.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\06\83\65.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\07\98\74.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\08\60\87.jpg
# ...

# %%
cols = [0,11]
df = pd.read_csv('Files/VIT_9.csv', names=['PID', 'Image'], usecols=cols)
df.head()
# Out:
#    PID                                              Image
# 0  PID                                              Image
# 1   30  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2   31  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3  148  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4  149  https://images.vgsi.com/photos2/WorcesterMAPho...

# %%
df = pd.read_csv('Files/VIT_9.csv')
df.shape
# Out:
# (2498, 17)

# %%
df.columns[11]
# Out:
# 'Image'

# %%
cols = [0,11]
df = pd.read_csv('Files/VIT_9.csv', usecols=cols)
df
# Out:
#          PID                                              Image
# 0         30  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1         31  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2        148  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3        149  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4        152  https://images.vgsi.com/photos2/WorcesterMAPho...
# ...      ...                                                ...
# 2493   62624  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2494   62634  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2495  187014  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2496  187015  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2497  187028  https://images.vgsi.com/photos2/WorcesterMAPho...
#
# [2498 rows x 2 columns]

# %%
df
# Out:
#          PID                                              Image
# 0         30  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1         31  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2        148  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3        149  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4        152  https://images.vgsi.com/photos2/WorcesterMAPho...
# ...      ...                                                ...
# 2493   62624  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2494   62634  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2495  187014  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2496  187015  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2497  187028  https://images.vgsi.com/photos2/WorcesterMAPho...
#
# [2498 rows x 2 columns]

# %%
opener=urllib.request.build_opener()
opener.addheaders=[('User-Agent','Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1941.0 Safari/537.36')]
urllib.request.install_opener(opener)

result = df['Image'].isna().any()

print(result)

missed_PID = []
missed_links = []


for index, row in df.iterrows():
    createFileName = 'Images/9/' + str(row['PID']) + '.jpg'
    image_url = str(row['Image'])
    print('Image_url',image_url)
    try:
        urllib.request.urlretrieve(image_url, createFileName)
    except:
        print('Missing Image for PID',str(row['PID']))
        print('Missing Image for PID',str(row['Image']))
        missed_PID.append(str(row['PID']))
        missed_links.append(str(row['Image']))
# Out:
# False
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\07\94\53.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\07\94\52.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\02\01-017-00052.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\00\45\82.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\02\01-017-0037A.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\02\01-017-0037B.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0141\IMG_2841_141836.JPG
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\02\01-017-31-1R.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\02\01-017-52-2A.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\02\01-017-52-3A.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\00\45\81.jpg
# ...

# %%
cols = [0,11]
df = pd.read_csv('Files/content___0.csv', names=['PID', 'Image'], usecols=cols)
df.head()
# Out:
#    PID                                              Image
# 0  PID                                              Image
# 1   12  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2   48  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3   53  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4   63  https://images.vgsi.com/photos2/WorcesterMAPho...

# %%
df = pd.read_csv('Files/content___0.csv')
df.shape
# Out:
# (2631, 17)

# %%
df.columns[11]
# Out:
# 'Image'

# %%
cols = [0,11]
df = pd.read_csv('Files/content___0.csv', usecols=cols)
df
# Out:
#         PID                                              Image
# 0        12  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1        48  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2        53  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3        63  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4        78  https://images.vgsi.com/photos2/WorcesterMAPho...
# ...     ...                                                ...
# 2626  60877  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2627  61018  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2628  61218  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2629  61393  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2630  61959  https://images.vgsi.com/photos2/WorcesterMAPho...
#
# [2631 rows x 2 columns]

# %%
df
# Out:
#         PID                                              Image
# 0        12  https://images.vgsi.com/photos2/WorcesterMAPho...
# 1        48  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2        53  https://images.vgsi.com/photos2/WorcesterMAPho...
# 3        63  https://images.vgsi.com/photos2/WorcesterMAPho...
# 4        78  https://images.vgsi.com/photos2/WorcesterMAPho...
# ...     ...                                                ...
# 2626  60877  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2627  61018  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2628  61218  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2629  61393  https://images.vgsi.com/photos2/WorcesterMAPho...
# 2630  61959  https://images.vgsi.com/photos2/WorcesterMAPho...
#
# [2631 rows x 2 columns]

# %%
opener=urllib.request.build_opener()
opener.addheaders=[('User-Agent','Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/36.0.1941.0 Safari/537.36')]
urllib.request.install_opener(opener)

result = df['Image'].isna().any()

print(result)

missed_PID = []
missed_links = []


for index, row in df.iterrows():
    createFileName = 'Images/0/' + str(row['PID']) + '.jpg'
    image_url = str(row['Image'])
    print('Image_url',image_url)
    try:
        urllib.request.urlretrieve(image_url, createFileName)
    except:
        print('Missing Image for PID',str(row['PID']))
        print('Missing Image for PID',str(row['Image']))
        missed_PID.append(str(row['PID']))
        missed_links.append(str(row['Image']))
# Out:
# False
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0139\IMG_0496_139971.JPG
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\08\19\78.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\01\01-011-00022.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\01\01-012-00011.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\01\01-013-0001A.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\01\01-014-00010.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\01\01-014-0001A.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\01\02\01-015-00002.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0131\20200915_104736_131054.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\00\13\95\97.jpg
# Image_url https://images.vgsi.com/photos2/WorcesterMAPhotos//\0130\P1070906_130679.jpg
# ...
